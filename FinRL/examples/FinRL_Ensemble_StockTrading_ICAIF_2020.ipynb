# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
#!pip install -q condacolab
#import condacolab
#condacolab.install()
#!apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import sys
print(sys.executable)

import site
print(site.getsitepackages())

import pkgutil
print(any(m.name == "finrl" for m in pkgutil.iter_modules()))

import subprocess
subprocess.run([sys.executable, "-m", "pip", "show", "finrl"])
# Out:
# d:\RELm\REL301m_AI_Trading\FinRL\.venv\Scripts\python.exe
# ['d:\\RELm\\REL301m_AI_Trading\\FinRL\\.venv', 'd:\\RELm\\REL301m_AI_Trading\\FinRL\\.venv\\lib\\site-packages']
# True
# CompletedProcess(args=['d:\\RELm\\REL301m_AI_Trading\\FinRL\\.venv\\Scripts\\python.exe', '-m', 'pip', 'show', 'finrl'], returncode=0)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AMZN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NVDA', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WMT', 'DIS', 'SHW']

# %%
# TRAIN_START_DATE = '2009-04-01'
# TRAIN_END_DATE = '2021-01-01'
# TEST_START_DATE = '2021-01-01'
# TEST_END_DATE = '2022-06-01'
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.config_tickers import DOW_30_TICKER

# TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2021-10-01'
# TEST_START_DATE = '2021-10-01'
# TEST_END_DATE = '2023-03-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94560, 8)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
INDICATORS = ['macd',
               'rsi_30',
               'cci_30',
               'dx_30']

# %%
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
#len(state), len(data)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 181

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity":5

}

# buy_cost_list = sell_cost_list = [0.001] * stock_dimension
# num_stock_shares = [0] * stock_dimension
# env_kwargs = {
#     "hmax": 100,
#     "initial_amount": 1000000,
#     "num_stock_shares": num_stock_shares,
#     "buy_cost_pct": buy_cost_list,
#     "sell_cost_pct": sell_cost_list,
#     "state_space": state_space,
#     "stock_dim": stock_dimension,
#     "tech_indicator_list": INDICATORS,
#     "action_space": stock_dimension,
#     "reward_scaling": 1e-4
# }

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)
# e_train_gym = StockTradingEnv(df = processed, **env_kwargs)
# agent = DRLAgent(e_train_gym)
# if_using_a2c = True
# model_a2c = agent.get_model("a2c")
# # if if_using_a2c:
# #   tmp_path = RESULTS_DIR + '/a2c'
# #   new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# #   model_a2c.set_logger(new_logger_a2c)
# trained_a2c = agent.train_model(model=model_a2c,
#                              tb_log_name='a2c',
#                              total_timesteps=50000)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

TD3_model_kwargs = {"batch_size": 100, "buffer_size": 1000000, "learning_rate": 0.0001}




timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000,
                 'sac' : 10_000,
                 'td3' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  230.98491071494556
# ======Model training from:  2014-01-06 to  2026-01-02
# ======a2c Training========
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_2
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 100        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -0.306     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 7.89       |
# |    reward             | -0.7365055 |
# |    reward_max         | 1.6056861  |
# |    reward_mean        | 0.20304744 |
# |    reward_min         | -0.7365055 |
# |    std                | 0.999      |
# |    value_loss         | 2.41       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 99           |
# |    iterations         | 200          |
# |    time_elapsed       | 10           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -42.6        |
# |    explained_variance | 0.0377       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 29           |
# |    reward             | 0.10641441   |
# |    reward_max         | 1.1309187    |
# |    reward_mean        | 0.3827402    |
# |    reward_min         | -0.055110943 |
# |    std                | 1            |
# |    value_loss         | 0.52         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -0.0956    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 48.8       |
# |    reward             | 0.8913794  |
# |    reward_max         | 0.8913794  |
# |    reward_mean        | 0.15342532 |
# |    reward_min         | -1.1297385 |
# |    std                | 1          |
# |    value_loss         | 1.86       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 94           |
# |    iterations         | 400          |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -42.7        |
# |    explained_variance | -0.0542      |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 292          |
# |    reward             | -1.8748679   |
# |    reward_max         | 3.853683     |
# |    reward_mean        | -0.023401702 |
# |    reward_min         | -1.8748679   |
# |    std                | 1            |
# |    value_loss         | 44.6         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 95         |
# |    iterations         | 500        |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -185       |
# |    reward             | -1.1662382 |
# |    reward_max         | 2.7161937  |
# |    reward_mean        | 0.56356806 |
# |    reward_min         | -2.924885  |
# |    std                | 1          |
# |    value_loss         | 19.4       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 95          |
# |    iterations         | 600         |
# |    time_elapsed       | 31          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -39.5       |
# |    reward             | -1.8648795  |
# |    reward_max         | 6.1575894   |
# |    reward_mean        | 0.062800005 |
# |    reward_min         | -5.5149145  |
# |    std                | 1           |
# |    value_loss         | 11.6        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 95          |
# |    iterations         | 700         |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -40.3       |
# |    reward             | -0.16789699 |
# |    reward_max         | 2.146145    |
# |    reward_mean        | 0.197036    |
# |    reward_min         | -1.3291609  |
# |    std                | 1           |
# |    value_loss         | 0.975       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 800         |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -34.6       |
# |    reward             | 1.4567456   |
# |    reward_max         | 1.4567456   |
# |    reward_mean        | 0.57201296  |
# |    reward_min         | -0.15130742 |
# |    std                | 1           |
# |    value_loss         | 1.81        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 900         |
# |    time_elapsed       | 46          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -0.222      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 49.9        |
# |    reward             | 1.6675009   |
# |    reward_max         | 1.6675009   |
# |    reward_mean        | 0.41905868  |
# |    reward_min         | -0.75686675 |
# |    std                | 0.998       |
# |    value_loss         | 1.82        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 96         |
# |    iterations         | 1000       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -19.4      |
# |    reward             | -1.3343651 |
# |    reward_max         | 1.3404539  |
# |    reward_mean        | -0.4638097 |
# |    reward_min         | -2.7747855 |
# |    std                | 0.998      |
# |    value_loss         | 0.385      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 97          |
# |    iterations         | 1100        |
# |    time_elapsed       | 56          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 3.07        |
# |    reward             | 1.6677241   |
# |    reward_max         | 1.897961    |
# |    reward_mean        | 0.9162524   |
# |    reward_min         | -0.40437904 |
# |    std                | 1           |
# |    value_loss         | 0.834       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 97         |
# |    iterations         | 1200       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 58.8       |
# |    reward             | 2.0654254  |
# |    reward_max         | 8.098029   |
# |    reward_mean        | 1.4978825  |
# |    reward_min         | -3.9145408 |
# |    std                | 0.999      |
# |    value_loss         | 6.27       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 1300       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 10.1       |
# |    reward             | -1.4337504 |
# |    reward_max         | 0.5217653  |
# |    reward_mean        | -0.3477036 |
# |    reward_min         | -1.4337504 |
# |    std                | 1          |
# |    value_loss         | 0.207      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1400        |
# |    time_elapsed       | 70          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 30          |
# |    reward             | 0.6076875   |
# |    reward_max         | 0.72446597  |
# |    reward_mean        | 0.26830024  |
# |    reward_min         | -0.37493867 |
# |    std                | 0.999       |
# |    value_loss         | 0.69        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1500        |
# |    time_elapsed       | 75          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -72.4       |
# |    reward             | -0.5125079  |
# |    reward_max         | 1.1779996   |
# |    reward_mean        | 0.04635676  |
# |    reward_min         | -0.94746584 |
# |    std                | 1           |
# |    value_loss         | 7.17        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1600       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 166        |
# |    reward             | 2.0641246  |
# |    reward_max         | 3.6214547  |
# |    reward_mean        | 1.6816504  |
# |    reward_min         | -0.6247548 |
# |    std                | 1          |
# |    value_loss         | 14.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1700       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -312       |
# |    reward             | -0.9248166 |
# |    reward_max         | 3.0495832  |
# |    reward_mean        | -0.3467688 |
# |    reward_min         | -4.463031  |
# |    std                | 1          |
# |    value_loss         | 57.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 1800      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -491      |
# |    reward             | 3.7292082 |
# |    reward_max         | 10.579337 |
# |    reward_mean        | 3.1159816 |
# |    reward_min         | -4.293684 |
# |    std                | 1         |
# |    value_loss         | 231       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1900       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -31.9      |
# |    reward             | 0.46791047 |
# |    reward_max         | 1.7308862  |
# |    reward_mean        | 0.6165541  |
# |    reward_min         | 0.07445501 |
# |    std                | 1          |
# |    value_loss         | 0.749      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 2000       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 79.7       |
# |    reward             | 0.83871245 |
# |    reward_max         | 1.2030945  |
# |    reward_mean        | 0.67510474 |
# |    reward_min         | 0.2922442  |
# |    std                | 1          |
# |    value_loss         | 6.72       |
# --------------------------------------
# ======a2c Validation from:  2026-01-02 to  2026-04-06
# a2c Sharpe Ratio:  -0.4236221162551788
# ======ddpg Training========
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_2
# day: 3015, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4005010.87
# total_reward: 3005010.87
# total_cost: 10031.87
# total_trades: 46287
# Sharpe: 0.781
# =================================
# ======ddpg Validation from:  2026-01-02 to  2026-04-06
# ddpg Sharpe Ratio:  -0.06319300904891059
# ======td3 Training========
# Using cpu device
# Logging to tensorboard_log/td3\td3_126_2
# day: 3015, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5314914.09
# total_reward: 4314914.09
# total_cost: 1672.83
# total_trades: 36742
# Sharpe: 0.898
# =================================
# ======td3 Validation from:  2026-01-02 to  2026-04-06
# td3 Sharpe Ratio:  -0.21205253292795248
# ======sac Training========
# Using cpu device
# Logging to tensorboard_log/sac\sac_126_2
# day: 3015, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5549059.27
# total_reward: 4549059.27
# total_cost: 353739.51
# total_trades: 76935
# Sharpe: 0.734
# =================================
# ======sac Validation from:  2026-01-02 to  2026-04-06
# sac Sharpe Ratio:  -0.40859673970379157
# ======ppo Training========
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_2
# -----------------------------------
# | time/              |            |
# |    fps             | 139        |
# |    iterations      | 1          |
# |    time_elapsed    | 14         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -3.7446778 |
# |    reward_max      | 14.23443   |
# |    reward_mean     | 0.08532412 |
# |    reward_min      | -19.761608 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019600878 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.00684     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0355     |
# |    reward               | -0.9714029  |
# |    reward_max           | 22.017427   |
# |    reward_mean          | 0.076945834 |
# |    reward_min           | -17.46672   |
# |    std                  | 1           |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013409579 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.00495     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0275     |
# |    reward               | 0.25969887  |
# |    reward_max           | 31.005087   |
# |    reward_mean          | 0.12815608  |
# |    reward_min           | -19.283249  |
# |    std                  | 1           |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 4           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016573885 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.026      |
# |    reward               | 1.0051817   |
# |    reward_max           | 17.448833   |
# |    reward_mean          | 0.09140886  |
# |    reward_min           | -26.46892   |
# |    std                  | 1           |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 5           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019181225 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.0052      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0204     |
# |    reward               | 0.77438575  |
# |    reward_max           | 43.56627    |
# |    reward_mean          | 0.2175909   |
# |    reward_min           | -29.5028    |
# |    std                  | 1.01        |
# |    value_loss           | 33.5        |
# -----------------------------------------
# ======ppo Validation from:  2026-01-02 to  2026-04-06
# ppo Sharpe Ratio:  -0.19960890853348875
# ======Best Model Retraining from:  2014-01-06 to  2026-04-06
# ======Trading from:  2026-04-06 to  2026-07-07
# Ensemble Strategy took:  11.7457719484965  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2026-01-02  2026-04-06       DDPG  -0.423622  -0.199609   -0.063193
#
#   SAC Sharpe TD3 Sharpe
# 0  -0.408597  -0.212053

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
# Test
print("len(unique_trade_date) =", len(unique_trade_date))
print("rebalance_window =", rebalance_window)
print("validation_window =", validation_window)
import os

print(os.listdir("results"))

from finrl.config import (
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
)

print(TRAIN_START_DATE)
print(TRAIN_END_DATE)
print(TEST_START_DATE)
print(TEST_END_DATE)

import finrl.config

print(finrl.config.__file__)
# Out:
# len(unique_trade_date) = 136
# rebalance_window = 63
# validation_window = 63
# ['account_rewards_trade_ensemble_126.csv', 'account_rewards_trade_ensemble_189.csv', 'account_rewards_trade_ensemble_252.csv', 'account_rewards_trade_ensemble_315.csv', 'account_rewards_validation_a2c_126.csv', 'account_rewards_validation_a2c_189.csv', 'account_rewards_validation_a2c_252.csv', 'account_rewards_validation_a2c_315.csv', 'account_rewards_validation_ddpg_126.csv', 'account_rewards_validation_ddpg_189.csv', 'account_rewards_validation_ddpg_252.csv', 'account_rewards_validation_ddpg_315.csv', 'account_rewards_validation_ppo_126.csv', 'account_rewards_validation_ppo_189.csv', 'account_rewards_validation_ppo_252.csv', 'account_rewards_validation_ppo_315.csv', 'account_rewards_validation_sac_126.csv', 'account_rewards_validation_sac_189.csv', 'account_rewards_validation_sac_252.csv', 'account_rewards_validation_sac_315.csv', 'account_rewards_validation_td3_126.csv', 'account_rewards_validation_td3_189.csv', 'account_rewards_validation_td3_252.csv', 'account_rewards_validation_td3_315.csv', 'account_value_trade_ensemble_126.csv', 'account_value_trade_ensemble_126.png', 'account_value_trade_ensemble_189.csv', 'account_value_trade_ensemble_189.png', 'account_value_trade_ensemble_252.csv', 'account_value_trade_ensemble_252.png', 'account_value_trade_ensemble_315.csv', 'account_value_trade_ensemble_315.png', 'account_value_validation_a2c_126.csv', 'account_value_validation_a2c_126.png', 'account_value_validation_a2c_189.csv', 'account_value_validation_a2c_189.png', 'account_value_validation_a2c_252.csv', 'account_value_validation_a2c_252.png', 'account_value_validation_a2c_315.csv', 'account_value_validation_a2c_315.png', 'account_value_validation_ddpg_126.csv', 'account_value_validation_ddpg_126.png', 'account_value_validation_ddpg_189.csv', 'account_value_validation_ddpg_189.png', 'account_value_validation_ddpg_252.csv', 'account_value_validation_ddpg_252.png', 'account_value_validation_ddpg_315.csv', 'account_value_validation_ddpg_315.png', 'account_value_validation_ppo_126.csv', 'account_value_validation_ppo_126.png', 'account_value_validation_ppo_189.csv', 'account_value_validation_ppo_189.png', 'account_value_validation_ppo_252.csv', 'account_value_validation_ppo_252.png', 'account_value_validation_ppo_315.csv', 'account_value_validation_ppo_315.png', 'account_value_validation_sac_126.csv', 'account_value_validation_sac_126.png', 'account_value_validation_sac_189.csv', 'account_value_validation_sac_189.png', 'account_value_validation_sac_252.csv', 'account_value_validation_sac_252.png', 'account_value_validation_sac_315.csv', 'account_value_validation_sac_315.png', 'account_value_validation_td3_126.csv', 'account_value_validation_td3_126.png', 'account_value_validation_td3_189.csv', 'account_value_validation_td3_189.png', 'account_value_validation_td3_252.csv', 'account_value_validation_td3_252.png', 'account_value_validation_td3_315.csv', 'account_value_validation_td3_315.png', 'actions_trade_ensemble_126.csv', 'actions_trade_ensemble_189.csv', 'actions_trade_ensemble_252.csv', 'actions_trade_ensemble_315.csv', 'actions_validation_a2c_126.csv', 'actions_validation_a2c_189.csv', 'actions_validation_a2c_252.csv', 'actions_validation_a2c_315.csv', 'actions_validation_ddpg_126.csv', 'actions_validation_ddpg_189.csv', 'actions_validation_ddpg_252.csv', 'actions_validation_ddpg_315.csv', 'actions_validation_ppo_126.csv', 'actions_validation_ppo_189.csv', 'actions_validation_ppo_252.csv', 'actions_validation_ppo_315.csv', 'actions_validation_sac_126.csv', 'actions_validation_sac_189.csv', 'actions_validation_sac_252.csv', 'actions_validation_sac_315.csv', 'actions_validation_td3_126.csv', 'actions_validation_td3_189.csv', 'actions_validation_td3_252.csv', 'actions_validation_td3_315.csv', 'last_state_ensemble_62.csv']
# 2014-01-06
# 2025-12-31
# 2026-01-01
# 2026-07-21
# D:\RELm\REL301m_AI_Trading\FinRL\finrl\config.py

# %%
df_trade_date = pd.DataFrame({'datadate': unique_trade_date})

# Đọc tất cả file account value
dfs = []

for i in range(rebalance_window + validation_window,
               len(unique_trade_date) + 1,
               rebalance_window):
    temp = pd.read_csv(
        'results/account_value_trade_{}_{}.csv'.format('ensemble', i)
    )
    dfs.append(temp)

# Ghép tất cả DataFrame
df_account_value = pd.concat(dfs, ignore_index=True)

# Tính Sharpe Ratio
sharpe = (252**0.5) * df_account_value.account_value.pct_change().mean() / df_account_value.account_value.pct_change().std()
print("Sharpe Ratio:", sharpe)

# Ghép ngày giao dịch
df_account_value = df_account_value.join(
    df_trade_date[validation_window:].reset_index(drop=True)
)
# Out:
# Sharpe Ratio: 4.50017367945267

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2026-04-06           NaN  2026-04-06
# 1   1.000915e+06  2026-04-07      0.000915  2026-04-07
# 2   1.021064e+06  2026-04-08      0.020130  2026-04-08
# 3   1.031249e+06  2026-04-09      0.009975  2026-04-09
# 4   1.025726e+06  2026-04-10     -0.005355  2026-04-10

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return           0.839290
# Cumulative returns      0.164562
# Annual volatility       0.139896
# Sharpe ratio            4.500174
# Calmar ratio           31.101060
# Stability               0.904503
# Max drawdown           -0.026986
# Omega ratio             2.094850
# Sortino ratio           8.580729
# Skew                         NaN
# Kurtosis                     NaN
# Tail ratio              1.657483
# Daily value at risk    -0.015127
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (62, 8)
# Annual return           0.664138
# Cumulative returns      0.133495
# Annual volatility       0.132040
# Sharpe ratio            3.989169
# Calmar ratio           20.840611
# Stability               0.900127
# Max drawdown           -0.031867
# Omega ratio             2.004876
# Sortino ratio           7.356569
# Skew                         NaN
# Kurtosis                     NaN
# Tail ratio              1.532835
# Daily value at risk    -0.014545
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:            date           dji
# 0   2026-04-06  1.000000e+06
# 1   2026-04-07  9.981697e+05
# 2   2026-04-08  1.026571e+06
# 3   2026-04-09  1.032482e+06
# 4   2026-04-10  1.026713e+06
# ..         ...           ...
# 58  2026-06-29  1.118125e+06
# 59  2026-06-30  1.121049e+06
# 60  2026-07-01  1.120749e+06
# 61  2026-07-02  1.133495e+06
# 62  2026-07-06           NaN
#
# [63 rows x 2 columns]
# df_dji:                       dji
# date
# 2026-04-06  1.000000e+06
# 2026-04-07  9.981697e+05
# 2026-04-08  1.026571e+06
# 2026-04-09  1.032482e+06
# 2026-04-10  1.026713e+06
# ...                  ...
# 2026-06-29  1.118125e+06
# 2026-06-30  1.121049e+06
# 2026-07-01  1.120749e+06
# 2026-07-02  1.133495e+06
# 2026-07-06           NaN
#
# [63 rows x 1 columns]

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value,
#               baseline_ticker = '^DJI',
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble':df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)

result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15, 5)
plt.figure()
result.plot()
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2026-01-02
# 1    2026-01-05
# 2    2026-01-06
# 3    2026-01-07
# 4    2026-01-08
# ..          ...
# 131  2026-07-14
# 132  2026-07-15
# 133  2026-07-16
# 134  2026-07-17
# 135  2026-07-20
#
# [136 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2026-04-06  1.000000e+06
# 2026-04-07  1.000915e+06
# 2026-04-08  1.021064e+06
# 2026-04-09  1.031249e+06
# 2026-04-10  1.025726e+06
# ...                  ...
# 2026-06-29  1.159387e+06
# 2026-06-30  1.168317e+06
# 2026-07-01  1.155807e+06
# 2026-07-02  1.164111e+06
# 2026-07-06  1.164562e+06
#
# [63 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2026-04-06  1.000000e+06  1.000000e+06
# 2026-04-07  1.000915e+06  9.981697e+05
# 2026-04-08  1.021064e+06  1.026571e+06
# 2026-04-09  1.031249e+06  1.032482e+06
# 2026-04-10  1.025726e+06  1.026713e+06
# ...                  ...           ...
# 2026-06-29  1.159387e+06  1.118125e+06
# 2026-06-30  1.168317e+06  1.121049e+06
# 2026-07-01  1.155807e+06  1.120749e+06
# 2026-07-02  1.164111e+06  1.133495e+06
# 2026-07-06  1.164562e+06           NaN
#
# [63 rows x 2 columns]
# <Axes: xlabel='date'>

# %% [markdown]
# <a id='6.3'></a>
# ## 7.3 Baseline Stats and Comparison to Stock Market Index
# In this section, we compare the ensemble strategy with the DJIA benchmark. We report the Sharpe ratio and max drawdown for both series.

# %%
comparison = pd.concat(
    [
        df_account_value.set_index('date')['account_value'].rename('ensemble'),
        df_dji['dji'].rename('dji')
    ],
    axis=1
).dropna()

comparison = comparison / comparison.iloc[0]


def max_drawdown(series):
    cumulative_max = np.maximum.accumulate(series)
    return ((series / cumulative_max) - 1).min()

ensemble_sharpe = (252 ** 0.5) * comparison['ensemble'].pct_change().mean() / comparison['ensemble'].pct_change().std()
dji_sharpe = (252 ** 0.5) * comparison['dji'].pct_change().mean() / comparison['dji'].pct_change().std()

print('Ensemble Sharpe Ratio:', ensemble_sharpe)
print('DJIA Sharpe Ratio:', dji_sharpe)
print('Ensemble Max Drawdown:', max_drawdown(comparison['ensemble']))
print('DJIA Max Drawdown:', max_drawdown(comparison['dji']))

plt.rcParams['figure.figsize'] = (15, 5)
comparison.plot()
plt.title('Ensemble Strategy vs DJIA')
plt.xlabel('Date')
plt.ylabel('Normalized Portfolio Value')
plt.show()
# Out:
# Ensemble Sharpe Ratio: 4.527135450023129
# DJIA Sharpe Ratio: 3.9891690362507677
# Ensemble Max Drawdown: -0.02698590391028355
# DJIA Max Drawdown: -0.03186747368569376
